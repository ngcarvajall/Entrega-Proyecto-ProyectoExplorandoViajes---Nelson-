# %%
import requests
import pandas as pd

# %%
import requests
#hago mi rquest
url = "https://booking-com15.p.rapidapi.com/api/v1/hotels/searchHotels"

querystring = {"dest_id":"-117543","search_type":"CITY","arrival_date":"2024-10-25","departure_date":"2024-10-28","adults":"1","room_qty":"1","page_number":"1","units":"metric","temperature_unit":"c","languagecode":"en-us","currency_code":"EUR"}

headers = {
	"x-rapidapi-key": "8bf68f7481msh7aa93c8e8e9a6ffp19eef8jsn33f2cc37fe85",
	"x-rapidapi-host": "booking-com15.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

datos= response.json()

# %%
#tengo mis datos a full
datos
# Out:
# {'status': True,
#  'message': 'Success',
#  'timestamp': 1729416977161,
#  'data': {'hotels': [{'hotel_id': 7797985,
#     'accessibilityLabel': 'Florence Heart Uffizi - Renovated and central.\n4 out of 5 for property rating.\n9.1 Wonderful 70 reviews.\n\u200eUffizi\u202c • \u200e500 m from downtown\u202c.\n Entire apartment – 55\xa0m² : 3\xa0beds • 2\xa0bedrooms • 1\xa0living room • 1\xa0bathroom.\nOriginal price 900 EUR. Current price 585 EUR..\n+77 EUR taxes and charges.',
#     'property': {'priceBreakdown': {'taxExceptions': [],
#       'excludedPrice': {'value': 76.5000000000001, 'currency': 'EUR'},
#       'strikethroughPrice': {'value': 900, 'currency': 'EUR'},
#       'grossPrice': {'value': 585, 'currency': 'EUR'},
#       'benefitBadges': [{'text': 'Limited-time Deal',
#         'identifier': 'Limited Time Deal',
#         'variant': 'constructive',
#         'explanation': 'Limited-time Deal'}]},
#      'wishlistName': 'Florence',
#      'qualityClass': 4,
#      'isFirstPage': True,
#      'currency': 'EUR',
#      'checkout': {'fromTime': '08:00', 'untilTime': '10:00'},
#      'reviewScore': 9.1,
#      'longitude': 11.2565933,
#      'countryCode': 'it',
#      'optOutFromGalleryChanges': 0,
#      'accuratePropertyClass': 0,
#      'checkin': {'fromTime': '15:00', 'untilTime': '20:00'},
#      'propertyClass': 0,
#      'name': 'Florence Heart Uffizi - Renovated and central',
#      'blockIds': ['779798501_336351912_1_0_0'],
#      'latitude': 43.7678655,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/322091192.jpg?k=f6b9caca233d2b776407800321fd05b8c412ab4e8a70f109dac1a1ce72c6d686&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/322091192.jpg?k=f6b9caca233d2b776407800321fd05b8c412ab4e8a70f109dac1a1ce72c6d686&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/322091192.jpg?k=f6b9caca233d2b776407800321fd05b8c412ab4e8a70f109dac1a1ce72c6d686&o='],
#      'ufi': -117543,
#      'position': 0,
#      'id': 7797985,
#      'reviewScoreWord': 'Wonderful',
#      'rankingPosition': 0,
#      'mainPhotoId': 322091192,
#      'checkoutDate': '2024-10-28',
#      'checkinDate': '2024-10-25',
#      'reviewCount': 70}},
#    {'hotel_id': 4758951,
#     'accessibilityLabel': 'Appartamento la Ninfea.\n4 out of 5 for property rating.\n8.9 Excellent 195 reviews.\n\u200eIn downtown\u202c.\n Entire apartment – 110\xa0m² : 5\xa0beds • 3\xa0bedrooms • 1\xa0living room • 3\xa0bathrooms.\n1842 EUR.\n+17 EUR taxes and charges.\nFree cancellation.',
#     'property': {'reviewScore': 8.9,
#      'checkout': {'untilTime': '10:00', 'fromTime': '07:00'},
#      'currency': 'EUR',
#      'isFirstPage': True,
#      'wishlistName': 'Florence',
#      'qualityClass': 4,
#      'priceBreakdown': {'taxExceptions': [],
#       'excludedPrice': {'currency': 'EUR', 'value': 16.5000000000001},
#       'grossPrice': {'value': 1842.38, 'currency': 'EUR'},
#       'benefitBadges': []},
#      'checkin': {'untilTime': '19:00', 'fromTime': '14:00'},
#      'propertyClass': 0,
#      'isPreferredPlus': True,
#      'accuratePropertyClass': 0,
#      'optOutFromGalleryChanges': 0,
#      'longitude': 11.2551467,
#      'countryCode': 'it',
#      'ufi': -117543,
#      'latitude': 43.7789623,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/186165708.jpg?k=df9900653f032f77445b24565ccc9abfb49db56dc9d05be197a3af201ebdda38&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/186165708.jpg?k=df9900653f032f77445b24565ccc9abfb49db56dc9d05be197a3af201ebdda38&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/186165708.jpg?k=df9900653f032f77445b24565ccc9abfb49db56dc9d05be197a3af201ebdda38&o='],
#      'blockIds': ['475895101_265834880_1_0_0'],
#      'name': 'Appartamento la Ninfea',
#      'isPreferred': True,
#      'reviewCount': 195,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'position': 1,
#      'reviewScoreWord': 'Excellent',
#      'mainPhotoId': 186165708,
#      'rankingPosition': 1,
#      'id': 4758951}},
#    {'hotel_id': 338716,
#     'accessibilityLabel': 'BorgoDeGreci Apartments.\n8.7 Excellent 468 reviews.\n\u200eUffizi\u202c • \u200e500 m from downtown\u202c.\n Entire apartment : 1\xa0bed • 1\xa0bedroom • 1\xa0living room • 1\xa0bathroom.\nOriginal price 656 EUR. Current price 591 EUR..\n+17 EUR taxes and charges.\nFree cancellation.',
#     'property': {'name': 'BorgoDeGreci Apartments',
#      'latitude': 43.769171465075,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/409188061.jpg?k=8c6af13ab2fb325110ebabc1afbed9a6f4d68e0eabb38134e7868e05c29df900&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/409188061.jpg?k=8c6af13ab2fb325110ebabc1afbed9a6f4d68e0eabb38134e7868e05c29df900&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/409188061.jpg?k=8c6af13ab2fb325110ebabc1afbed9a6f4d68e0eabb38134e7868e05c29df900&o='],
#      'blockIds': ['33871619_343667248_2_0_0'],
#      'ufi': -117543,
#      'position': 2,
#      'reviewScoreWord': 'Excellent',
#      'rankingPosition': 2,
#      'mainPhotoId': 409188061,
#      'id': 338716,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'isPreferred': True,
#      'reviewCount': 468,
#      'priceBreakdown': {'taxExceptions': [],
#       'excludedPrice': {'value': 16.5000000000001, 'currency': 'EUR'},
#       'strikethroughPrice': {'currency': 'EUR', 'value': 656.25},
#       'grossPrice': {'currency': 'EUR', 'value': 590.63},
#       'benefitBadges': [{'explanation': 'Mobile-only price',
#         'identifier': 'Mobile Rate',
#         'variant': 'constructive',
#         'text': 'Mobile-only price'}]},
#      'wishlistName': 'Florence',
#      'qualityClass': 0,
#      'checkout': {'fromTime': '06:00', 'untilTime': '10:00'},
#      'currency': 'EUR',
#      'isFirstPage': True,
#      'reviewScore': 8.7,
#      'longitude': 11.2588439136744,
#      'countryCode': 'it',
#      'optOutFromGalleryChanges': 0,
#      'accuratePropertyClass': 0,
#      'checkin': {'untilTime': '00:00', 'fromTime': '14:00'},
#      'isPreferredPlus': True,
#      'propertyClass': 0}},
#    {'hotel_id': 418291,
#     'accessibilityLabel': 'B&B Le Stanze del Duomo.\n4 out of 5 for property rating.\n8.5 Very Good 6580 reviews.\n\u200eDuomo\u202c • \u200e350 m from downtown\u202c.\n Private room : Beds: 1 double or 2 twins.\n619 EUR.\n+62 EUR taxes and charges.',
#     'property': {'ufi': -117543,
#      'latitude': 43.7743650648138,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/420305037.jpg?k=baac2c4f0b45034c6095f5d465bfd1a0d454b5508daebc4d1799feefe5d2221c&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/420305037.jpg?k=baac2c4f0b45034c6095f5d465bfd1a0d454b5508daebc4d1799feefe5d2221c&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/420305037.jpg?k=baac2c4f0b45034c6095f5d465bfd1a0d454b5508daebc4d1799feefe5d2221c&o='],
#      'blockIds': ['41829103_0_1_0_0'],
#      'name': 'B&B Le Stanze del Duomo',
#      'isPreferred': True,
#      'reviewCount': 6580,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'position': 3,
#      'reviewScoreWord': 'Very Good',
#      'rankingPosition': 3,
#      'mainPhotoId': 420305037,
#      'id': 418291,
#      'reviewScore': 8.5,
#      'checkout': {'untilTime': '11:00', 'fromTime': '08:00'},
#      'currency': 'EUR',
#      'isFirstPage': True,
#      'wishlistName': 'Florence',
#      'qualityClass': 4,
#      'priceBreakdown': {'benefitBadges': [],
#       'grossPrice': {'value': 619.3046249153, 'currency': 'EUR'},
#       'excludedPrice': {'value': 61.9203312459001, 'currency': 'EUR'},
#       'taxExceptions': []},
#      'checkin': {'untilTime': '21:00', 'fromTime': '14:00'},
#      'propertyClass': 0,
#      'isPreferredPlus': True,
#      'accuratePropertyClass': 0,
#      'optOutFromGalleryChanges': 0,
#      'longitude': 11.2557721138,
#      'countryCode': 'it'}},
#    {'hotel_id': 80511,
#     'accessibilityLabel': 'Adler Cavalieri Hotel-Private Spa & Gym.\n4 out of 5 stars.\n8.5 Very Good 3628 reviews.\n\u200eSanta Maria Novella\u202c • \u200e800 m from downtown\u202c.\n Hotel room : 1\xa0bed.\n722 EUR.\n+21 EUR taxes and charges.\nFree cancellation.\nNo prepayment needed.',
#     'property': {'longitude': 11.2456655502319,
#      'countryCode': 'it',
#      'optOutFromGalleryChanges': 0,
#      'accuratePropertyClass': 4,
#      'checkin': {'fromTime': '15:00', 'untilTime': '00:00'},
#      'propertyClass': 4,
#      'isPreferredPlus': True,
#      'priceBreakdown': {'benefitBadges': [],
#       'grossPrice': {'currency': 'EUR', 'value': 722},
#       'excludedPrice': {'currency': 'EUR', 'value': 21.0000000000001},
#       'taxExceptions': []},
#      'wishlistName': 'Florence',
#      'qualityClass': 0,
#      'checkout': {'untilTime': '12:00', 'fromTime': '00:00'},
#      'currency': 'EUR',
#      'isFirstPage': True,
#      'reviewScore': 8.5,
#      'position': 4,
#      'rankingPosition': 4,
#      'reviewScoreWord': 'Very Good',
#      'mainPhotoId': 323487924,
#      'id': 80511,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'isPreferred': True,
#      'reviewCount': 3628,
#      'name': 'Adler Cavalieri Hotel-Private Spa & Gym',
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/323487924.jpg?k=1e3ec897ede16a4bf955ca2b3afb7cd5d6a3ce87cb76ad025bdb8668466a3ab3&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/323487924.jpg?k=1e3ec897ede16a4bf955ca2b3afb7cd5d6a3ce87cb76ad025bdb8668466a3ab3&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/323487924.jpg?k=1e3ec897ede16a4bf955ca2b3afb7cd5d6a3ce87cb76ad025bdb8668466a3ab3&o='],
#      'latitude': 43.7754844913328,
#      'blockIds': ['8051119_388647664_2_2_0'],
#      'ufi': -117543}},
#    {'hotel_id': 4682549,
#     'accessibilityLabel': 'Pietrapiana Boutique Apartments.\n4 out of 5 for property rating.\n9.4 Wonderful 1306 reviews.\n\u200eSanta Croce\u202c • \u200e900 m from downtown\u202c.\n Entire apartment – 65\xa0m² : 3\xa0beds • 2\xa0bedrooms • 1\xa0living room • 2\xa0bathrooms.\nOriginal price 712 EUR. Current price 641 EUR..\n+57 EUR taxes and charges.',
#     'property': {'blockIds': ['468254901_144943436_1_0_0'],
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/243130784.jpg?k=830aa2a9342f9b5d0e076e4834c1990d8f3976ed87576c93970e19ffd510f949&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/243130784.jpg?k=830aa2a9342f9b5d0e076e4834c1990d8f3976ed87576c93970e19ffd510f949&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/243130784.jpg?k=830aa2a9342f9b5d0e076e4834c1990d8f3976ed87576c93970e19ffd510f949&o='],
#      'latitude': 43.771486,
#      'name': 'Pietrapiana Boutique Apartments',
#      'ufi': -117543,
#      'id': 4682549,
#      'mainPhotoId': 243130784,
#      'reviewScoreWord': 'Wonderful',
#      'rankingPosition': 5,
#      'position': 5,
#      'reviewCount': 1306,
#      'isPreferred': True,
#      'checkoutDate': '2024-10-28',
#      'checkinDate': '2024-10-25',
#      'qualityClass': 4,
#      'wishlistName': 'Florence',
#      'priceBreakdown': {'grossPrice': {'value': 640.87, 'currency': 'EUR'},
#       'benefitBadges': [{'variant': 'constructive',
#         'identifier': 'Mobile Rate',
#         'text': 'Mobile-only price',
#         'explanation': 'Mobile-only price'}],
#       'taxExceptions': [],
#       'strikethroughPrice': {'currency': 'EUR', 'value': 712.08},
#       'excludedPrice': {'currency': 'EUR', 'value': 56.5000000000001}},
#      'reviewScore': 9.4,
#      'isFirstPage': True,
#      'checkout': {'untilTime': '11:00', 'fromTime': '06:00'},
#      'currency': 'EUR',
#      'optOutFromGalleryChanges': 0,
#      'countryCode': 'it',
#      'longitude': 11.265324,
#      'propertyClass': 0,
#      'isPreferredPlus': True,
#      'checkin': {'untilTime': '00:00', 'fromTime': '14:30'},
#      'accuratePropertyClass': 0}},
#    {'hotel_id': 1000691,
#     'accessibilityLabel': 'Lodges le Mura.\n3 out of 5 for property rating.\n9.1 Wonderful 309 reviews.\n\u200eIn downtown\u202c.\n Entire apartment – 40\xa0m² : 3\xa0beds • 1\xa0bedroom • 1\xa0living room • 2\xa0bathrooms.\nOriginal price 621 EUR. Current price 559 EUR..\n+57 EUR taxes and charges.',
#     'property': {'position': 6,
#      'id': 1000691,
#      'reviewScoreWord': 'Wonderful',
#      'rankingPosition': 6,
#      'mainPhotoId': 27810575,
#      'isPreferred': True,
#      'reviewCount': 309,
#      'checkoutDate': '2024-10-28',
#      'checkinDate': '2024-10-25',
#      'blockIds': ['100069110_123963078_0_0_0'],
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/27810575.jpg?k=05b26e46c1bedc3414f48c609ccb7842560e7cddcb977621d3c3840920fbddb2&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/27810575.jpg?k=05b26e46c1bedc3414f48c609ccb7842560e7cddcb977621d3c3840920fbddb2&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/27810575.jpg?k=05b26e46c1bedc3414f48c609ccb7842560e7cddcb977621d3c3840920fbddb2&o='],
#      'latitude': 43.7620184,
#      'name': 'Lodges le Mura',
#      'ufi': -117543,
#      'optOutFromGalleryChanges': 0,
#      'longitude': 11.2424978,
#      'countryCode': 'it',
#      'checkin': {'fromTime': '14:00', 'untilTime': '00:00'},
#      'isPreferredPlus': True,
#      'propertyClass': 0,
#      'accuratePropertyClass': 0,
#      'wishlistName': 'Florence',
#      'qualityClass': 3,
#      'priceBreakdown': {'grossPrice': {'value': 558.9, 'currency': 'EUR'},
#       'benefitBadges': [{'text': 'Mobile-only price',
#         'identifier': 'Mobile Rate',
#         'variant': 'constructive',
#         'explanation': 'Mobile-only price'}],
#       'taxExceptions': [],
#       'excludedPrice': {'currency': 'EUR', 'value': 56.5000000000001},
#       'strikethroughPrice': {'value': 621, 'currency': 'EUR'}},
#      'reviewScore': 9.1,
#      'isFirstPage': True,
#      'checkout': {'fromTime': '08:00', 'untilTime': '10:00'},
#      'currency': 'EUR'}},
#    {'hotel_id': 253753,
#     'accessibilityLabel': 'Hostel Archi Rossi.\n8.6 Excellent 4802 reviews.\n\u200eSanta Maria Novella\u202c • \u200e800 m from downtown\u202c.\n Bed in dorm : 1\xa0bed.\n145 EUR.\n+12 EUR taxes and charges.\nFree cancellation.',
#     'property': {'isFirstPage': True,
#      'currency': 'EUR',
#      'checkout': {'fromTime': '04:00', 'untilTime': '10:30'},
#      'reviewScore': 8.6,
#      'priceBreakdown': {'excludedPrice': {'value': 12.0000000000001,
#        'currency': 'EUR'},
#       'taxExceptions': [],
#       'benefitBadges': [],
#       'grossPrice': {'value': 145, 'currency': 'EUR'}},
#      'wishlistName': 'Florence',
#      'qualityClass': 0,
#      'accuratePropertyClass': 0,
#      'checkin': {'fromTime': '15:00', 'untilTime': '23:00'},
#      'propertyClass': 0,
#      'longitude': 11.2507295608521,
#      'countryCode': 'it',
#      'optOutFromGalleryChanges': 0,
#      'ufi': -117543,
#      'name': 'Hostel Archi Rossi',
#      'blockIds': ['25375305_396216182_0_0_0'],
#      'latitude': 43.7783759234141,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/153087184.jpg?k=6467005b7d3cbf2ffde3a6effe93475df13e56ebb11ecbc485a36697e24f3edb&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/153087184.jpg?k=6467005b7d3cbf2ffde3a6effe93475df13e56ebb11ecbc485a36697e24f3edb&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/153087184.jpg?k=6467005b7d3cbf2ffde3a6effe93475df13e56ebb11ecbc485a36697e24f3edb&o='],
#      'checkoutDate': '2024-10-28',
#      'checkinDate': '2024-10-25',
#      'isPreferred': True,
#      'reviewCount': 4802,
#      'position': 7,
#      'id': 253753,
#      'mainPhotoId': 153087184,
#      'reviewScoreWord': 'Excellent',
#      'rankingPosition': 7}},
#    {'hotel_id': 83869,
#     'accessibilityLabel': 'Relais Piazza Signoria.\n4 out of 5 for property rating.\n9.0 Wonderful 2468 reviews.\n\u200eSanta Maria Novella\u202c • \u200e250 m from downtown\u202c.\n Entire apartment – 50\xa0m² : 2\xa0beds • 1\xa0bedroom • 1\xa0living room • 1\xa0bathroom.\nOriginal price 1296 EUR. Current price 1166 EUR..\n+17 EUR taxes and charges.',
#     'property': {'isFirstPage': True,
#      'currency': 'EUR',
#      'checkout': {'fromTime': '00:00', 'untilTime': '11:00'},
#      'reviewScore': 9,
#      'priceBreakdown': {'excludedPrice': {'currency': 'EUR',
#        'value': 16.5000000000001},
#       'strikethroughPrice': {'currency': 'EUR', 'value': 1296},
#       'taxExceptions': [],
#       'benefitBadges': [{'explanation': 'Mobile-only price',
#         'text': 'Mobile-only price',
#         'identifier': 'Mobile Rate',
#         'variant': 'constructive'}],
#       'grossPrice': {'currency': 'EUR', 'value': 1166.4}},
#      'wishlistName': 'Florence',
#      'qualityClass': 4,
#      'accuratePropertyClass': 0,
#      'checkin': {'untilTime': '17:00', 'fromTime': '14:00'},
#      'propertyClass': 0,
#      'isPreferredPlus': True,
#      'longitude': 11.2547153234482,
#      'countryCode': 'it',
#      'optOutFromGalleryChanges': 0,
#      'ufi': -117543,
#      'name': 'Relais Piazza Signoria',
#      'blockIds': ['8386905_88437361_2_0_0'],
#      'latitude': 43.7693719349657,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/14796757.jpg?k=af1dd3e5a36bf4377d687f001b47f4b1cc4e5cd24d8d84f5ea32751595aa6184&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/14796757.jpg?k=af1dd3e5a36bf4377d687f001b47f4b1cc4e5cd24d8d84f5ea32751595aa6184&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/14796757.jpg?k=af1dd3e5a36bf4377d687f001b47f4b1cc4e5cd24d8d84f5ea32751595aa6184&o='],
#      'checkoutDate': '2024-10-28',
#      'checkinDate': '2024-10-25',
#      'isPreferred': True,
#      'reviewCount': 2468,
#      'position': 8,
#      'id': 83869,
#      'mainPhotoId': 14796757,
#      'reviewScoreWord': 'Wonderful',
#      'rankingPosition': 8}},
#    {'hotel_id': 1418373,
#     'accessibilityLabel': "The Artists' Palace Florence.\n4 out of 5 for property rating.\n9.0 Wonderful 903 reviews.\n\u200eDuomo\u202c • \u200e350 m from downtown\u202c.\n Private room : Beds: 1 double or 2 twins.\n698 EUR.\n+70 EUR taxes and charges.",
#     'property': {'checkoutDate': '2024-10-28',
#      'checkinDate': '2024-10-25',
#      'reviewCount': 903,
#      'isPreferred': True,
#      'id': 1418373,
#      'reviewScoreWord': 'Wonderful',
#      'rankingPosition': 9,
#      'mainPhotoId': 49529689,
#      'position': 9,
#      'ufi': -117543,
#      'name': "The Artists' Palace Florence",
#      'blockIds': ['141837301_0_1_0_0'],
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/49529689.jpg?k=e76866677a46941c404172beb995794c0f0472129be28d9e1f5f816a4fab32cf&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/49529689.jpg?k=e76866677a46941c404172beb995794c0f0472129be28d9e1f5f816a4fab32cf&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/49529689.jpg?k=e76866677a46941c404172beb995794c0f0472129be28d9e1f5f816a4fab32cf&o='],
#      'latitude': 43.7746446192836,
#      'accuratePropertyClass': 0,
#      'propertyClass': 0,
#      'isPreferredPlus': True,
#      'checkin': {'untilTime': '20:00', 'fromTime': '14:00'},
#      'countryCode': 'it',
#      'longitude': 11.2549856491084,
#      'optOutFromGalleryChanges': 0,
#      'isFirstPage': True,
#      'checkout': {'untilTime': '11:00', 'fromTime': '09:00'},
#      'currency': 'EUR',
#      'reviewScore': 9,
#      'priceBreakdown': {'excludedPrice': {'value': 69.8227028373001,
#        'currency': 'EUR'},
#       'taxExceptions': [],
#       'benefitBadges': [],
#       'grossPrice': {'currency': 'EUR', 'value': 698.227028373}},
#      'qualityClass': 4,
#      'wishlistName': 'Florence'}},
#    {'hotel_id': 85585,
#     'accessibilityLabel': 'Hotel Ariele.\n4 out of 5 stars.\n9.2 Wonderful 1657 reviews.\n\u200eSanta Maria Novella\u202c • \u200e1.3 km from downtown\u202c.\n Hotel room : 2\xa0beds.\n650 EUR.\n+78 EUR taxes and charges.',
#     'property': {'name': 'Hotel Ariele',
#      'latitude': 43.7754283268337,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/388172610.jpg?k=2a4adb0db3d0d44f1a57f793edadd8e4f0382dc7504115a9203ba469be231a60&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/388172610.jpg?k=2a4adb0db3d0d44f1a57f793edadd8e4f0382dc7504115a9203ba469be231a60&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/388172610.jpg?k=2a4adb0db3d0d44f1a57f793edadd8e4f0382dc7504115a9203ba469be231a60&o='],
#      'blockIds': ['8558501_0_1_1_0'],
#      'ufi': -117543,
#      'rankingPosition': 10,
#      'reviewScoreWord': 'Wonderful',
#      'mainPhotoId': 388172610,
#      'id': 85585,
#      'position': 10,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'reviewCount': 1657,
#      'isPreferred': True,
#      'priceBreakdown': {'grossPrice': {'currency': 'EUR',
#        'value': 649.5878391257},
#       'benefitBadges': [],
#       'taxExceptions': [],
#       'excludedPrice': {'value': 78.4434718461001, 'currency': 'EUR'}},
#      'qualityClass': 0,
#      'wishlistName': 'Florence',
#      'checkout': {'untilTime': '12:00', 'fromTime': '07:00'},
#      'currency': 'EUR',
#      'isFirstPage': True,
#      'reviewScore': 9.2,
#      'countryCode': 'it',
#      'longitude': 11.2391558289528,
#      'optOutFromGalleryChanges': 1,
#      'accuratePropertyClass': 4,
#      'propertyClass': 4,
#      'isPreferredPlus': True,
#      'checkin': {'fromTime': '14:00', 'untilTime': '23:30'}}},
#    {'hotel_id': 6696497,
#     'accessibilityLabel': 'Street Art Inn Florence.\n3 out of 5 for property rating.\n8.4 Very Good 391 reviews.\n\u200eSanta Maria Novella\u202c • \u200e1.3 km from downtown\u202c.\n Private room : 1\xa0bed.\nOriginal price 489 EUR. Current price 440 EUR..\n+17 EUR taxes and charges.',
#     'property': {'name': 'Street Art Inn Florence',
#      'blockIds': ['669649707_273789395_1_0_0'],
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/504217338.jpg?k=07d0190da3904cdb544147a9a033b387ed64efa5114f96e9220ddb770000e1fd&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/504217338.jpg?k=07d0190da3904cdb544147a9a033b387ed64efa5114f96e9220ddb770000e1fd&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/504217338.jpg?k=07d0190da3904cdb544147a9a033b387ed64efa5114f96e9220ddb770000e1fd&o='],
#      'latitude': 43.7812450579593,
#      'ufi': -117543,
#      'id': 6696497,
#      'reviewScoreWord': 'Very Good',
#      'rankingPosition': 11,
#      'mainPhotoId': 504217338,
#      'position': 11,
#      'checkoutDate': '2024-10-28',
#      'checkinDate': '2024-10-25',
#      'reviewCount': 391,
#      'isPreferred': True,
#      'priceBreakdown': {'grossPrice': {'currency': 'EUR', 'value': 439.67},
#       'benefitBadges': [{'explanation': 'Mobile-only price',
#         'text': 'Mobile-only price',
#         'identifier': 'Mobile Rate',
#         'variant': 'constructive'}],
#       'taxExceptions': [],
#       'excludedPrice': {'value': 16.5000000000001, 'currency': 'EUR'},
#       'strikethroughPrice': {'currency': 'EUR', 'value': 488.52}},
#      'qualityClass': 3,
#      'wishlistName': 'Florence',
#      'isFirstPage': True,
#      'currency': 'EUR',
#      'checkout': {'fromTime': '00:00', 'untilTime': '11:00'},
#      'reviewScore': 8.4,
#      'countryCode': 'it',
#      'longitude': 11.243519767984,
#      'optOutFromGalleryChanges': 0,
#      'accuratePropertyClass': 0,
#      'propertyClass': 0,
#      'isPreferredPlus': True,
#      'checkin': {'untilTime': '00:00', 'fromTime': '14:00'}}},
#    {'hotel_id': 276866,
#     'accessibilityLabel': 'Hotel Art Atelier.\n4 out of 5 stars.\n8.9 Excellent 1345 reviews.\n\u200eSanta Maria Novella\u202c • \u200e450 m from downtown\u202c.\n Hotel room : 1\xa0bed.\n811 EUR.\n+81 EUR taxes and charges.',
#     'property': {'ufi': -117543,
#      'latitude': 43.7753152230046,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/232500266.jpg?k=1fe75da32e3f2660d1d93e58d9e53be0478226865216e498be0daf4c90ce618d&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/232500266.jpg?k=1fe75da32e3f2660d1d93e58d9e53be0478226865216e498be0daf4c90ce618d&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/232500266.jpg?k=1fe75da32e3f2660d1d93e58d9e53be0478226865216e498be0daf4c90ce618d&o='],
#      'blockIds': ['27686614_0_1_1_0'],
#      'name': 'Hotel Art Atelier',
#      'isPreferred': True,
#      'reviewCount': 1345,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'position': 12,
#      'reviewScoreWord': 'Excellent',
#      'mainPhotoId': 232500266,
#      'rankingPosition': 12,
#      'id': 276866,
#      'reviewScore': 8.9,
#      'currency': 'EUR',
#      'checkout': {'fromTime': '04:00', 'untilTime': '11:00'},
#      'isFirstPage': True,
#      'wishlistName': 'Florence',
#      'qualityClass': 0,
#      'priceBreakdown': {'grossPrice': {'currency': 'EUR',
#        'value': 811.2825193805},
#       'benefitBadges': [],
#       'taxExceptions': [],
#       'excludedPrice': {'currency': 'EUR', 'value': 81.1236468264001}},
#      'checkin': {'untilTime': '00:00', 'fromTime': '14:00'},
#      'isPreferredPlus': True,
#      'propertyClass': 4,
#      'accuratePropertyClass': 4,
#      'optOutFromGalleryChanges': 0,
#      'longitude': 11.2519191205502,
#      'countryCode': 'it'}},
#    {'hotel_id': 11712061,
#     'accessibilityLabel': 'Ruby Bea Hotel Florence.\n4 out of 5 stars.\n8.8 Excellent 164 reviews.\n\u200eCampo Di Marte\u202c • \u200e1.5 km from downtown\u202c.\n Hotel room : 1\xa0bed.\n557 EUR.\n+21 EUR taxes and charges.',
#     'property': {'position': 13,
#      'id': 11712061,
#      'rankingPosition': 13,
#      'reviewScoreWord': 'Excellent',
#      'mainPhotoId': 584089345,
#      'isPreferred': True,
#      'reviewCount': 164,
#      'checkoutDate': '2024-10-28',
#      'checkinDate': '2024-10-25',
#      'blockIds': ['1171206102_389666127_0_2_0'],
#      'latitude': 43.783608063873,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/584089345.jpg?k=eacd4a3a1eb8f62389f2cce0d326e650cf4b4561603e9fcdb5ebf43ae9f66fa7&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/584089345.jpg?k=eacd4a3a1eb8f62389f2cce0d326e650cf4b4561603e9fcdb5ebf43ae9f66fa7&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/584089345.jpg?k=eacd4a3a1eb8f62389f2cce0d326e650cf4b4561603e9fcdb5ebf43ae9f66fa7&o='],
#      'name': 'Ruby Bea Hotel Florence',
#      'ufi': -117543,
#      'optOutFromGalleryChanges': 0,
#      'longitude': 11.26320082994,
#      'countryCode': 'it',
#      'checkin': {'fromTime': '15:00', 'untilTime': '00:00'},
#      'propertyClass': 4,
#      'isPreferredPlus': True,
#      'accuratePropertyClass': 4,
#      'wishlistName': 'Florence',
#      'qualityClass': 0,
#      'priceBreakdown': {'excludedPrice': {'currency': 'EUR',
#        'value': 21.0000000000001},
#       'taxExceptions': [],
#       'benefitBadges': [],
#       'grossPrice': {'value': 557, 'currency': 'EUR'}},
#      'reviewScore': 8.8,
#      'isFirstPage': True,
#      'checkout': {'fromTime': '00:00', 'untilTime': '11:00'},
#      'currency': 'EUR'}},
#    {'hotel_id': 81788,
#     'accessibilityLabel': '"il Pitti" Soggiorno.\n7.8 Good 2031 reviews.\n\u200eSanto Spirito\u202c • \u200e800 m from downtown\u202c.\n Private room : 2\xa0beds.\n481 EUR.\n+48 EUR taxes and charges.',
#     'property': {'accuratePropertyClass': 0,
#      'isPreferredPlus': True,
#      'propertyClass': 0,
#      'checkin': {'untilTime': '00:00', 'fromTime': '14:00'},
#      'countryCode': 'it',
#      'longitude': 11.2491028010845,
#      'optOutFromGalleryChanges': 0,
#      'currency': 'EUR',
#      'checkout': {'untilTime': '10:30', 'fromTime': '00:00'},
#      'isFirstPage': True,
#      'reviewScore': 7.8,
#      'priceBreakdown': {'taxExceptions': [],
#       'excludedPrice': {'value': 48.1049962959001, 'currency': 'EUR'},
#       'grossPrice': {'currency': 'EUR', 'value': 481.4275821143},
#       'benefitBadges': []},
#      'qualityClass': 0,
#      'wishlistName': 'Florence',
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'reviewCount': 2031,
#      'isPreferred': True,
#      'reviewScoreWord': 'Good',
#      'mainPhotoId': 125050186,
#      'rankingPosition': 14,
#      'id': 81788,
#      'position': 14,
#      'ufi': -117543,
#      'name': '"il Pitti" Soggiorno',
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/125050186.jpg?k=76a9d7b24b7e8627b843eac060b134b6fb0ed3c2cf0f89f4a55ba21273363dc8&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/125050186.jpg?k=76a9d7b24b7e8627b843eac060b134b6fb0ed3c2cf0f89f4a55ba21273363dc8&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/125050186.jpg?k=76a9d7b24b7e8627b843eac060b134b6fb0ed3c2cf0f89f4a55ba21273363dc8&o='],
#      'latitude': 43.7656452157469,
#      'blockIds': ['8178810_0_1_0_0']}},
#    {'hotel_id': 12458,
#     'accessibilityLabel': 'Hotel Residence La Contessina.\n3 out of 5 for property rating.\n8.4 Very Good 1457 reviews.\n\u200eSanta Maria Novella\u202c • \u200e700 m from downtown\u202c.\n Private room : 1\xa0bed.\nOriginal price 599 EUR. Current price 539 EUR..\n+18 EUR taxes and charges.',
#     'property': {'isPreferred': True,
#      'reviewCount': 1457,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'position': 15,
#      'rankingPosition': 15,
#      'reviewScoreWord': 'Very Good',
#      'mainPhotoId': 159332330,
#      'id': 12458,
#      'ufi': -117543,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/159332330.jpg?k=43ac5eb4b5520523c710f45a4a1d4524d44c68b5de363c31f3a0ce7e8de2f639&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/159332330.jpg?k=43ac5eb4b5520523c710f45a4a1d4524d44c68b5de363c31f3a0ce7e8de2f639&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/159332330.jpg?k=43ac5eb4b5520523c710f45a4a1d4524d44c68b5de363c31f3a0ce7e8de2f639&o='],
#      'latitude': 43.777698105265,
#      'blockIds': ['1245810_95135892_0_0_0'],
#      'name': 'Hotel Residence La Contessina',
#      'checkin': {'untilTime': '19:00', 'fromTime': '14:00'},
#      'propertyClass': 0,
#      'isPreferredPlus': True,
#      'accuratePropertyClass': 0,
#      'optOutFromGalleryChanges': 0,
#      'longitude': 11.2510567903519,
#      'countryCode': 'it',
#      'reviewScore': 8.4,
#      'currency': 'EUR',
#      'checkout': {'fromTime': '00:00', 'untilTime': '10:00'},
#      'isFirstPage': True,
#      'wishlistName': 'Florence',
#      'qualityClass': 3,
#      'priceBreakdown': {'taxExceptions': [],
#       'strikethroughPrice': {'value': 599.28, 'currency': 'EUR'},
#       'excludedPrice': {'value': 18.0000000000001, 'currency': 'EUR'},
#       'grossPrice': {'currency': 'EUR', 'value': 539.35},
#       'benefitBadges': [{'explanation': 'Mobile-only price',
#         'identifier': 'Mobile Rate',
#         'variant': 'constructive',
#         'text': 'Mobile-only price'}]}}},
#    {'hotel_id': 283123,
#     'accessibilityLabel': 'B&B Antiche Armonie.\n4 out of 5 for property rating.\n8.8 Excellent 1201 reviews.\n\u200eSanta Maria Novella\u202c • \u200e1.4 km from downtown\u202c.\n Private room : Beds: 1 double or 2 twins.\nOriginal price 614 EUR. Current price 553 EUR..\n+17 EUR taxes and charges.',
#     'property': {'priceBreakdown': {'grossPrice': {'value': 552.69,
#        'currency': 'EUR'},
#       'benefitBadges': [{'text': 'Mobile-only price',
#         'identifier': 'Mobile Rate',
#         'variant': 'constructive',
#         'explanation': 'Mobile-only price'}],
#       'taxExceptions': [],
#       'excludedPrice': {'value': 16.5000000000001, 'currency': 'EUR'},
#       'strikethroughPrice': {'currency': 'EUR', 'value': 614.1}},
#      'qualityClass': 4,
#      'wishlistName': 'Florence',
#      'currency': 'EUR',
#      'checkout': {'untilTime': '10:00', 'fromTime': '00:00'},
#      'isFirstPage': True,
#      'reviewScore': 8.8,
#      'countryCode': 'it',
#      'longitude': 11.2440951168537,
#      'optOutFromGalleryChanges': 0,
#      'accuratePropertyClass': 0,
#      'propertyClass': 0,
#      'isPreferredPlus': True,
#      'checkin': {'fromTime': '10:00', 'untilTime': '17:00'},
#      'name': 'B&B Antiche Armonie',
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/94522592.jpg?k=cc95c61ddf49ee0c2bcf4510b4cc4fdc1f84bc5e64dbf70172baa344baf5bd07&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/94522592.jpg?k=cc95c61ddf49ee0c2bcf4510b4cc4fdc1f84bc5e64dbf70172baa344baf5bd07&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/94522592.jpg?k=cc95c61ddf49ee0c2bcf4510b4cc4fdc1f84bc5e64dbf70172baa344baf5bd07&o='],
#      'latitude': 43.7824591310321,
#      'blockIds': ['28312302_88452829_1_1_0'],
#      'ufi': -117543,
#      'reviewScoreWord': 'Excellent',
#      'rankingPosition': 16,
#      'mainPhotoId': 94522592,
#      'id': 283123,
#      'position': 16,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'reviewCount': 1201,
#      'isPreferred': True}},
#    {'hotel_id': 49281,
#     'accessibilityLabel': "Palazzo Niccolini al Duomo Residenza D'Epoca.\n9.3 Wonderful 635 reviews.\n\u200eDuomo\u202c • \u200e350 m from downtown\u202c.\n Hotel room : 2\xa0beds.\n1769 EUR.\n+21 EUR taxes and charges.\nFree cancellation.",
#     'property': {'position': 17,
#      'reviewScoreWord': 'Wonderful',
#      'rankingPosition': 17,
#      'mainPhotoId': 171448683,
#      'id': 49281,
#      'isPreferred': True,
#      'reviewCount': 635,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/171448683.jpg?k=72c773888e70fdc9edc5d84b422f6fec9aee44ed755edb372e397cfaa44b8ab3&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/171448683.jpg?k=72c773888e70fdc9edc5d84b422f6fec9aee44ed755edb372e397cfaa44b8ab3&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/171448683.jpg?k=72c773888e70fdc9edc5d84b422f6fec9aee44ed755edb372e397cfaa44b8ab3&o='],
#      'latitude': 43.7736930114912,
#      'blockIds': ['4928108_369966723_2_1_0'],
#      'name': "Palazzo Niccolini al Duomo Residenza D'Epoca",
#      'ufi': -117543,
#      'optOutFromGalleryChanges': 0,
#      'longitude': 11.2574431300163,
#      'countryCode': 'it',
#      'checkin': {'fromTime': '14:00', 'untilTime': '21:00'},
#      'isPreferredPlus': True,
#      'propertyClass': 0,
#      'accuratePropertyClass': 0,
#      'wishlistName': 'Florence',
#      'qualityClass': 0,
#      'priceBreakdown': {'taxExceptions': [],
#       'excludedPrice': {'value': 21.0000000000001, 'currency': 'EUR'},
#       'grossPrice': {'currency': 'EUR', 'value': 1769},
#       'benefitBadges': []},
#      'reviewScore': 9.3,
#      'currency': 'EUR',
#      'checkout': {'fromTime': '08:00', 'untilTime': '11:00'},
#      'isFirstPage': True}},
#    {'hotel_id': 21993,
#     'accessibilityLabel': 'B&B Old Florence Inn.\n4 out of 5 for property rating.\n8.5 Very Good 1031 reviews.\n\u200eSanta Maria Novella\u202c • \u200e550 m from downtown\u202c.\n Private room : 2\xa0beds.\nOriginal price 689 EUR. Current price 620 EUR..\n+17 EUR taxes and charges.',
#     'property': {'accuratePropertyClass': 0,
#      'isPreferredPlus': True,
#      'propertyClass': 0,
#      'checkin': {'fromTime': '09:00', 'untilTime': '19:00'},
#      'countryCode': 'it',
#      'longitude': 11.2502004951239,
#      'optOutFromGalleryChanges': 0,
#      'currency': 'EUR',
#      'checkout': {'fromTime': '06:00', 'untilTime': '11:00'},
#      'isFirstPage': True,
#      'reviewScore': 8.5,
#      'priceBreakdown': {'taxExceptions': [],
#       'excludedPrice': {'value': 16.5000000000001, 'currency': 'EUR'},
#       'strikethroughPrice': {'value': 689, 'currency': 'EUR'},
#       'grossPrice': {'value': 620.1, 'currency': 'EUR'},
#       'benefitBadges': [{'explanation': 'Mobile-only price',
#         'text': 'Mobile-only price',
#         'identifier': 'Mobile Rate',
#         'variant': 'constructive'}]},
#      'qualityClass': 4,
#      'wishlistName': 'Florence',
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'reviewCount': 1031,
#      'isPreferred': True,
#      'reviewScoreWord': 'Very Good',
#      'rankingPosition': 18,
#      'mainPhotoId': 41691059,
#      'id': 21993,
#      'position': 18,
#      'ufi': -117543,
#      'name': 'B&B Old Florence Inn',
#      'latitude': 43.7761294109377,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/41691059.jpg?k=d91623b404421c8d325b28bf00d75aae337c324e8014a918239f1b0279c28d6a&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/41691059.jpg?k=d91623b404421c8d325b28bf00d75aae337c324e8014a918239f1b0279c28d6a&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/41691059.jpg?k=d91623b404421c8d325b28bf00d75aae337c324e8014a918239f1b0279c28d6a&o='],
#      'blockIds': ['2199303_95146286_0_1_0']}},
#    {'hotel_id': 80574,
#     'accessibilityLabel': 'Hotel Magenta.\n3 out of 5 stars.\n8.6 Excellent 2374 reviews.\n\u200eSanta Maria Novella\u202c • \u200e900 m from downtown\u202c.\n Hotel room : 1\xa0bed.\n571 EUR.\n+18 EUR taxes and charges.\nFree cancellation.\nNo prepayment needed.',
#     'property': {'latitude': 43.7738140709248,
#      'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/265745181.jpg?k=2eb5610cbdd2f1bd419d8e3b07ff98523becb7853da16cad78c9c871a43542b1&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square1024/265745181.jpg?k=2eb5610cbdd2f1bd419d8e3b07ff98523becb7853da16cad78c9c871a43542b1&o=',
#       'https://cf.bstatic.com/xdata/images/hotel/square2000/265745181.jpg?k=2eb5610cbdd2f1bd419d8e3b07ff98523becb7853da16cad78c9c871a43542b1&o='],
#      'blockIds': ['8057401_368821246_0_1_0'],
#      'name': 'Hotel Magenta',
#      'ufi': -117543,
#      'reviewScoreWord': 'Excellent',
#      'mainPhotoId': 265745181,
#      'rankingPosition': 19,
#      'id': 80574,
#      'position': 19,
#      'reviewCount': 2374,
#      'isPreferred': True,
#      'checkinDate': '2024-10-25',
#      'checkoutDate': '2024-10-28',
#      'qualityClass': 0,
#      'wishlistName': 'Florence',
#      'priceBreakdown': {'taxExceptions': [],
#       'excludedPrice': {'value': 18.0000000000001, 'currency': 'EUR'},
#       'grossPrice': {'value': 571, 'currency': 'EUR'},
#       'benefitBadges': []},
#      'reviewScore': 8.6,
#      'checkout': {'untilTime': '10:30', 'fromTime': '07:00'},
#      'currency': 'EUR',
#      'isFirstPage': True,
#      'optOutFromGalleryChanges': 0,
#      'countryCode': 'it',
#      'longitude': 11.2431107461452,
#      'isPreferredPlus': True,
#      'propertyClass': 3,
#      'checkin': {'fromTime': '13:30', 'untilTime': '00:00'},
#      'accuratePropertyClass': 3}}],
#   'meta': [{'title': '1151 properties'}],
#   'appear': [{'id': 'cma',
#     'component': {'props': {'content': {'props': {'items': [{'props': {'component': {'props': {'items': [{'props': {'text': [{'text': 'Read more on how payments affect the order of listed properties',
#                   'font': 'body_2'},
#                  {'color': 'foreground', 'text': '  ', 'font': 'strong_2'},
#                  {'font': 'body_2',
#                   'text': 'Learn more',
#                   'color': 'action_foreground',
#                   'linkActions': [{'props': {'url': 'booking://webview?url=https%3A%2F%2Fm.booking.com%2Fgeneral.en-us.html%3Faid%3D332731%3Btmpl%3Ddocs%2Fterms-and-conditions'}}]}]}}],
#              'spacing': 'spacing_half'}}}},
#          {'props': {}},
#          {'props': {'component': {'props': {'icon': 'close',
#              'tertiaryTintedColor': 'foreground',
#              'variant': 'tertiary_tinted',
#              'accessibilityLabel': 'Close'}}}}],
#         'fitContentWidth': True}},
#       'fill': True}}},
#    {'id': 'banner_qualityrating',
#     'component': {'props': {'text': "Properties with these icons have been awarded Booking.com's quality rating for homes",
#       'title': ''}}},
#    {'contentUrl': 'https://mobile-apps.booking.com/json/mobile.saba?route_path=saba-chat-entrypoint&add_bh_info=1&add_genius_percentage_value=1&add_ribbon_text=1&affiliate_id=332731&arrival_date=2024-10-25&autoextend=1&booked_x_times_for_dates=1&booked_x_times_threshold=1&categories_filter_additional_data=&change_popularity_sort_option_copy_tag=1&change_sort_options_copy_tags=1&check_excluded_charge_or_tax=1&check_flexible_dates=1&check_is_candidate_wholesaler=1&currency_code=EUR&dark_mode=1&deeplink_sec_since_click=168567.9046729803&departure_date=2024-10-28&dest_ids=-117543&device_id=57d11ec8bad14e119e4c15a86202c23f&distance_unit=metric&dl_sr_adoption=1&dotd=2&exposure_api_version=2.17&fix_dotd=1&flex_window=0&generate_map_bounding_box=1&get_cny_campaign_banner=1&get_skiing_info=1&guest_qty=1&include_amazon_banner=1&include_apartment_config=1&include_badges_in_price_breakdown=1&include_beach_information=1&include_bh_quality_classification=1&include_block_ids=1&include_bsb_info=1&include_bwallet_hotel_eligibility=1&include_composite_breakdown=1&include_cpc_non_trader_copy=1&include_excluded_charges_detail=1&include_free_cancellation=1&include_genius_badge=1&include_last_reservation=1&include_nr_bookings_best_range_message=1&include_nr_bookings_today=1&include_offered_bed_types=1&include_preview_cards=1&include_rack_rate_savings=1&include_rtb=1&include_ski_information=1&languagecode=en-us&location_source=recents&mark_first_highlighted_hotel=1&min_saba_version=31&network_type=wifi&new_segments_carousel=1&offset=0&optimized_call=1&outcome=search_results&page_define_enabled=1&pref_match=0&reason=change_sort_options&remove_wishlist_padding=1&room_qty=1&rows=auto&saba=1&saba_payload_root=1&saba_version=50&sb_calendar_open=1&search_type=city&send_ranking_version=1&send_search_id=1&show_beach_filter_badge=1&show_city_distance=1&show_distance_to_beach=1&show_distance_to_nearest_public_transport=1&show_genius_free_breakfast=0&show_if_mobile_deal=1&show_negotiated_rates=1&show_no_prepayment=1&show_policy=1&show_review_score_breakdowns=1&show_selected_filter_values=1&show_soldout=1&sort_by=auto&sort_by_source=sort_options&sort_genius_new_copy=1&source=search_results&temperature_unit=c&travel_purpose=&unfiltered_count_enabled=1&units=metric&use_dest_based_list_creation=1&use_direct_payment=1&user_os=15.5&user_version=36.8-iphone&categories_filter=price%3A%3AEUR-min-max&page=search-results'},
#    {'id': 'signin_now',
#     'component': {'props': {'title': 'Sign in and save money',
#       'text': 'Get instant access to our Genius loyalty program and enjoy discounts at properties worldwide.'}}}]}}

# %%
clean = datos['data']
#empiezo a adentrarme en mis diccionarios

# %%
#busco mis keys
clean.keys()
# Out:
# dict_keys(['hotels', 'meta', 'appear'])

# %%
#al encontrar la info, paso a seguir buscando
hoteles = clean['hotels']

# %%
hoteles[0]['property']
# Out:
# {'priceBreakdown': {'taxExceptions': [],
#   'excludedPrice': {'value': 76.5000000000001, 'currency': 'EUR'},
#   'strikethroughPrice': {'value': 900, 'currency': 'EUR'},
#   'grossPrice': {'value': 585, 'currency': 'EUR'},
#   'benefitBadges': [{'text': 'Limited-time Deal',
#     'identifier': 'Limited Time Deal',
#     'variant': 'constructive',
#     'explanation': 'Limited-time Deal'}]},
#  'wishlistName': 'Florence',
#  'qualityClass': 4,
#  'isFirstPage': True,
#  'currency': 'EUR',
#  'checkout': {'fromTime': '08:00', 'untilTime': '10:00'},
#  'reviewScore': 9.1,
#  'longitude': 11.2565933,
#  'countryCode': 'it',
#  'optOutFromGalleryChanges': 0,
#  'accuratePropertyClass': 0,
#  'checkin': {'fromTime': '15:00', 'untilTime': '20:00'},
#  'propertyClass': 0,
#  'name': 'Florence Heart Uffizi - Renovated and central',
#  'blockIds': ['779798501_336351912_1_0_0'],
#  'latitude': 43.7678655,
#  'photoUrls': ['https://cf.bstatic.com/xdata/images/hotel/square500/322091192.jpg?k=f6b9caca233d2b776407800321fd05b8c412ab4e8a70f109dac1a1ce72c6d686&o=',
#   'https://cf.bstatic.com/xdata/images/hotel/square1024/322091192.jpg?k=f6b9caca233d2b776407800321fd05b8c412ab4e8a70f109dac1a1ce72c6d686&o=',
#   'https://cf.bstatic.com/xdata/images/hotel/square2000/322091192.jpg?k=f6b9caca233d2b776407800321fd05b8c412ab4e8a70f109dac1a1ce72c6d686&o='],
#  'ufi': -117543,
#  'position': 0,
#  'id': 7797985,
#  'reviewScoreWord': 'Wonderful',
#  'rankingPosition': 0,
#  'mainPhotoId': 322091192,
#  'checkoutDate': '2024-10-28',
#  'checkinDate': '2024-10-25',
#  'reviewCount': 70}

# %%
#saco el nombre
hoteles[0]['property']['name']
# Out:
# 'Florence Heart Uffizi - Renovated and central'

# %%
#saco la cantidad de reviews
hoteles[0]['property']['reviewCount']
# Out:
# 70

# %%
#saco el score
hoteles[0]['property']['reviewScore']
# Out:
# 9.1

# %%
# precio por las noches
hoteles[0]['property']['priceBreakdown']['grossPrice']['value']
# Out:
# 585

# %%
hoteles[0]['property']['checkin']['fromTime']
# Out:
# '15:00'

# %%
hoteles[0]['property']['checkin']['untilTime']
# Out:
# '20:00'

# %%
hoteles[0]['property']['checkout']['fromTime']
# Out:
# '08:00'

# %%
hoteles[0]['property']['checkout']['untilTime']
# Out:
# '10:00'

# %%
#lista vacía para meter cosas
lista_datos_dicc = []
for i in range(0,(len(hoteles))):
     ciudad = hoteles[i]['property']['wishlistName']
     nombre = hoteles[i]['property']['name']
     reviewcount = hoteles[i]['property']['reviewCount']
     reviewscore = hoteles[i]['property']['reviewScore']
     precio = hoteles[i]['property']['priceBreakdown']['grossPrice']['value']
     hora_entrada1 = hoteles[i]['property']['checkin']['fromTime']
     hora_entrada2 = hoteles[i]['property']['checkin']['untilTime']
     hora_salida1 = hoteles[i]['property']['checkout']['fromTime']
     hora_salida2 = hoteles[i]['property']['checkout']['untilTime']
     dicc = {
     'Ciudad': ciudad,
     'Hotel': nombre,
     'Cantidad de reviews':reviewcount,
     'Calificación': reviewscore,
     'Precio': precio,
     'Entrada desde': hora_entrada1,
     'Entrada hasta': hora_entrada2,
     'Salida desde': hora_salida1,
     'Salida hasta': hora_salida2}
     lista_datos_dicc.append(dicc)

# %%
df = pd.DataFrame(lista_datos_dicc)

# %%
df.dtypes
# Out:
# Ciudad                  object
# Hotel                   object
# Cantidad de reviews      int64
# Calificación           float64
# Precio                 float64
# Entrada desde           object
# Entrada hasta           object
# Salida desde            object
# Salida hasta            object
# dtype: object

# %%
df.to_csv('datos/alojamientos_florencia.csv', index=False)

# %%
# lista_datos_dicc = []
# for i in range(0,(len(hoteles))-1):
#     dato_hotel = hoteles[i]['accessibilityLabel']
#     nombre = dato_hotel.split('\n')[0]
#     specs = dato_hotel.split('\n')[4]
#     precio = dato_hotel.split('\n')[5]
#     dicc = {
#     'Hotel': nombre,
#     'Especificaciones':specs,
#     'Precio': precio}
#     lista_datos_dicc.append(dicc)

# %%
# df = pd.DataFrame(lista_datos_dicc)
# df

# %%
import requests

url = "https://booking-com15.p.rapidapi.com/api/v1/hotels/searchHotels"

querystring = {"dest_id":"-2167973","search_type":"CITY","arrival_date":"2024-10-25","departure_date":"2024-10-28","adults":"1","room_qty":"1","page_number":"1","units":"metric","temperature_unit":"c","languagecode":"en-us","currency_code":"EUR"}

headers = {
	"x-rapidapi-key": "8bf68f7481msh7aa93c8e8e9a6ffp19eef8jsn33f2cc37fe85",
	"x-rapidapi-host": "booking-com15.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

datos_lisboa = response.json()

# %%
hoteles_lisboa = datos_lisboa['data']['hotels']

# %%
len(hoteles_lisboa)
# Out:
# 20

# %%
hoteles_lisboa[0]['property'].keys()
# Out:
# dict_keys(['reviewScoreWord', 'accuratePropertyClass', 'latitude', 'position', 'qualityClass', 'wishlistName', 'countryCode', 'optOutFromGalleryChanges', 'reviewCount', 'longitude', 'checkin', 'checkinDate', 'currency', 'ufi', 'rankingPosition', 'blockIds', 'checkoutDate', 'name', 'mainPhotoId', 'photoUrls', 'isFirstPage', 'priceBreakdown', 'checkout', 'id', 'reviewScore', 'propertyClass'])

# %%
hoteles_lisboa[0]['property']['wishlistName']
hoteles_lisboa[0]['property']['name']
hoteles_lisboa[0]['property']['reviewCount']
hoteles_lisboa[0]['property']['reviewScore']
hoteles_lisboa[0]['property']['priceBreakdown']['grossPrice']['value']
# Out:
# 'Quarto com Varanda e WC Partilhado no Chiado Lisboa Centro Histórico de Lisboa'

# %%
lista_dicc_lisboa = []
for i in range(0,(len(hoteles_lisboa))):
     city = hoteles_lisboa[i]['property']['wishlistName']
     name = hoteles_lisboa[i]['property']['name']
     rc = hoteles_lisboa[i]['property']['reviewCount']
     rsc = hoteles_lisboa[i]['property']['reviewScore']
     price = hoteles_lisboa[i]['property']['priceBreakdown']['grossPrice']['value']
     hora_entradal = hoteles_lisboa[i]['property']['checkin']['fromTime']
     hora_entradal2 = hoteles_lisboa[i]['property']['checkin']['untilTime']
     hora_salidal = hoteles_lisboa[i]['property']['checkout']['fromTime']
     hora_salidal2 = hoteles_lisboa[i]['property']['checkout']['untilTime']
     diccionario = {
     'Ciudad': city,
     'Hotel': name,
     'Cantidad de reviews':rc,
     'Calificación': rsc,
     'Precio': price,
     'Entrada desde': hora_entradal,
     'Entrada hasta': hora_entradal2,
     'Salida desde': hora_salidal,
     'Salida hasta': hora_salidal2}
     lista_dicc_lisboa.append(diccionario)

# %%
df_lisboa = pd.DataFrame(lista_dicc_lisboa)

# %%
df_lisboa.dtypes
# Out:
# Ciudad                  object
# Hotel                   object
# Cantidad de reviews      int64
# Calificación           float64
# Precio                 float64
# Entrada desde           object
# Entrada hasta           object
# Salida desde            object
# Salida hasta            object
# dtype: object

# %%
df_lisboa.to_csv('datos/alojamientos_lisboa.csv', index=False)

# %%
df_vacio = pd.DataFrame()

df_vacio = pd.concat([df_vacio,df,df_lisboa],ignore_index=True)

# %%
df_vacio['Precio'].round
# Out:
#       Ciudad                                              Hotel  \
# 0   Florence      Florence Heart Uffizi - Renovated and central
# 1   Florence                             Appartamento la Ninfea
# 2   Florence                            BorgoDeGreci Apartments
# 3   Florence                            B&B Le Stanze del Duomo
# 4   Florence            Adler Cavalieri Hotel-Private Spa & Gym
# 5   Florence                    Pietrapiana Boutique Apartments
# 6   Florence                                     Lodges le Mura
# 7   Florence                                 Hostel Archi Rossi
# 8   Florence                             Relais Piazza Signoria
# 9   Florence                       The Artists' Palace Florence
# 10  Florence                                       Hotel Ariele
# 11  Florence                            Street Art Inn Florence
# 12  Florence                                  Hotel Art Atelier
# 13  Florence                            Ruby Bea Hotel Florence
# 14  Florence                               "il Pitti" Soggiorno
# 15  Florence                      Hotel Residence La Contessina
# 16  Florence                                B&B Antiche Armonie
# 17  Florence       Palazzo Niccolini al Duomo Residenza D'Epoca
# 18  Florence                               B&B Old Florence Inn
# 19  Florence                                      Hotel Magenta
# 20    Lisbon  Quarto com Varanda e WC Partilhado no Chiado L...
# 21    Lisbon                                   Cais Urban Lodge
# 22    Lisbon                Lisbon Serviced Apartments - Campos
# 23    Lisbon                          Pensão Amor Madam's Lodge
# 24    Lisbon                          Upon Angels - Adults Only
# 25    Lisbon                                 TURIM Iberia Hotel
# 26    Lisbon                                 TURIM Lisboa Hotel
# 27    Lisbon      Superb Apartments Overlooking Graça in Lisbon
# 28    Lisbon                          Sant Jordi Hostels Lisbon
# 29    Lisbon                              Browns Downtown Hotel
# 30    Lisbon                          Esqina Cosmopolitan Lodge
# 31    Lisbon                               Browns Central Hotel
# 32    Lisbon                                         JAM Lisbon
# 33    Lisbon                               TURIM Saldanha Hotel
# 34    Lisbon                                    Luzeiros Suites
# 35    Lisbon                                   toctoctoc lisboa
# 36    Lisbon                                    Lux Lisboa Park
# 37    Lisbon                                TURIM Marques Hotel
# 38    Lisbon                       TURIM Terreiro do Paço Hotel
# 39    Lisbon                           Hotel Dom Carlos Liberty
#
#     Cantidad de reviews  Calificación       Precio Entrada desde  \
# 0                    70           9.1   585.000000         15:00
# 1                   195           8.9  1842.380000         14:00
# 2                   468           8.7   590.630000         14:00
# 3                  6580           8.5   619.304625         14:00
# 4                  3628           8.5   722.000000         15:00
# 5                  1306           9.4   640.870000         14:30
# 6                   309           9.1   558.900000         14:00
# 7                  4802           8.6   145.000000         15:00
# 8                  2468           9.0  1166.400000         14:00
# 9                   903           9.0   698.227028         14:00
# 10                 1657           9.2   649.587839         14:00
# 11                  391           8.4   439.670000         14:00
# 12                 1345           8.9   811.282519         14:00
# 13                  164           8.8   557.000000         15:00
# 14                 2031           7.8   481.427582         14:00
# 15                 1457           8.4   539.350000         14:00
# 16                 1201           8.8   552.690000         10:00
# 17                  635           9.3  1769.000000         14:00
# 18                 1031           8.5   620.100000         09:00
# 19                 2374           8.6   571.000000         13:30
# 20                    5           7.2   216.000000         15:00
# 21                 1382           8.8   627.501724         15:00
# 22                 4803           8.1   284.199860         14:00
# 23                  979           8.9   486.000000         17:00
# 24                  884           9.1   655.200000         15:00
# 25                 5874           8.3   470.559519         14:00
# 26                 2922           7.9   476.536954         14:00
# 27                  215           9.4   918.000000         15:00
# 28                 3557           8.7    81.870000         15:00
# 29                 3717           8.6   606.576096         15:00
# 30                 1150           8.6   856.615238         15:00
# 31                 4873           8.9  1001.713096         15:00
# 32                 1793           8.8   404.520000         15:00
# 33                 4208           8.2   500.879574         14:00
# 34                 4192           8.3   372.600000         14:00
# 35                  610           9.5   502.610000         15:00
# 36                 5717           8.8   526.806352         15:00
# 37                 5087           8.2   635.192260         14:00
# 38                 5858           7.9   741.745333         14:00
# 39                 3067           8.4   726.300000         15:00
#
#    Entrada hasta Salida desde Salida hasta
# 0          20:00        08:00        10:00
# 1          19:00        07:00        10:00
# 2          00:00        06:00        10:00
# 3          21:00        08:00        11:00
# 4          00:00        00:00        12:00
# 5          00:00        06:00        11:00
# 6          00:00        08:00        10:00
# 7          23:00        04:00        10:30
# 8          17:00        00:00        11:00
# 9          20:00        09:00        11:00
# 10         23:30        07:00        12:00
# 11         00:00        00:00        11:00
# 12         00:00        04:00        11:00
# 13         00:00        00:00        11:00
# 14         00:00        00:00        10:30
# 15         19:00        00:00        10:00
# 16         17:00        00:00        10:00
# 17         21:00        08:00        11:00
# 18         19:00        06:00        11:00
# 19         00:00        07:00        10:30
# 20         00:00        08:00        11:00
# 21         00:00        00:00        12:00
# 22         00:00        00:00        12:00
# 23         00:00        00:00        14:00
# 24         00:00        00:00        12:00
# 25         00:00        00:00        12:00
# 26         00:00        00:00        12:00
# 27         00:00        00:00        11:00
# 28         00:00        00:00        11:00
# 29         00:00        00:00        12:00
# 30         00:00        00:00        12:00
# 31         00:00        00:00        12:00
# 32         00:00        00:00        11:00
# 33         00:00        00:00        12:00
# 34         00:00        00:00        12:00
# 35         20:00        07:30        11:00
# 36         00:00        00:00        12:00
# 37         00:00        00:00        12:00
# 38         00:00        00:00        12:00
# 39         23:30        06:00        12:00

# %%
df_vacio.to_csv('datos/alojamientos_combinados.csv', index=False)
