# %%
import requests
import pandas as pd
import json
import dotenv as dotenv
import os
dotenv.load_dotenv()
api_key_viajes=os.getenv("api_key_viajes")

# %%
import requests

url = "https://sky-scrapper.p.rapidapi.com/api/v2/flights/searchFlights"

querystring = {"originSkyId":"MAD","destinationSkyId":"LIS","originEntityId":"95565077","destinationEntityId":"95565055","date":"2024-10-25","returnDate":"2024-10-28","cabinClass":"economy","adults":"1","sortBy":"best","limit":"25","currency":"EUR"}

headers = {
	"x-rapidapi-key": api_key_viajes,
	"x-rapidapi-host": "sky-scrapper.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

viajes = response.json()

# %%
with open('vuelos.json', 'w') as archivo_json:
    json.dump(viajes, archivo_json, indent=4)

# %%
viajes['data'].keys()
# Out:
# dict_keys(['context', 'itineraries', 'messages', 'filterStats', 'flightsSessionId', 'destinationImageUrl'])

# %%
info_vuelo = len(viajes['data']['itineraries'])

# %%
precios = viajes['data']['itineraries'][0]['price']['raw']

# %%
id_inicio = viajes['data']['itineraries'][0]['legs'][0]['origin']['id']

# %%
inicio_ciudad = viajes['data']['itineraries'][0]['legs'][0]['origin']['name']

# %%
id_regreso = viajes['data']['itineraries'][0]['legs'][0]['destination']['id']
id_regreso
# Out:
# 'LIS'

# %%
regreso_ciudad = viajes['data']['itineraries'][0]['legs'][0]['destination']['name']
regreso_ciudad
# Out:
# 'Lisbon'

# %%
tiempo = viajes['data']['itineraries'][0]['legs'][0]['durationInMinutes']
tiempo
# Out:
# 80

# %%
paradas = viajes['data']['itineraries'][0]['legs'][0]['stopCount']
paradas
# Out:
# 0

# %%
linea_aerea = viajes['data']['itineraries'][1]['legs'][1]['carriers']['marketing'][0]['name']
linea_aerea
# Out:
# 'Iberia'

# %%
hora_salida = viajes['data']['itineraries'][0]['legs'][0]['departure']
hora_salida
# Out:
# '2024-10-25T22:35:00'

# %%
hora_llegada = viajes['data']['itineraries'][0]['legs'][0]['arrival']
hora_llegada
# Out:
# '2024-10-25T22:55:00'

# %%
len(viajes['data']['itineraries'])
# Out:
# 10

# %%
viajes
# Out:
# {'status': True,
#  'timestamp': 1729356589590,
#  'sessionId': '8861858c-a929-47b3-8059-7946da419997',
#  'data': {'context': {'status': 'incomplete',
#    'sessionId': 'ClQIARJQCk4KJDg4NjE4NThjLWE5MjktNDdiMy04MDU5LTc5NDZkYTQxOTk5NxACGiRkYTkwOGI3My03NmI3LTRjMzQtOTZkZS1jYTUwZmEzYjMyODASKHVzc185OGU1YTE5MC1hOTUzLTRhMjktOWNjNi03ZGQ3MmI1ZDgwMDM=',
#    'totalResults': 10},
#   'itineraries': [{'id': '13870-2410252235--32356-0-13577-2410252255|13577-2410281505--32356-0-13870-2410281725',
#     'price': {'raw': 154.36,
#      'formatted': '155 €',
#      'pricingOptionId': 'pCQU846YRcaY'},
#     'legs': [{'id': '13870-2410252235--32356-0-13577-2410252255',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T22:35:00',
#       'arrival': '2024-10-25T22:55:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252235-2410252255--32356',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T22:35:00',
#         'arrival': '2024-10-25T22:55:00',
#         'durationInMinutes': 80,
#         'flightNumber': '6724',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410281505--32356-0-13870-2410281725',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T15:05:00',
#       'arrival': '2024-10-28T17:25:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410281505-2410281725--32356',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T15:05:00',
#         'arrival': '2024-10-28T17:25:00',
#         'durationInMinutes': 80,
#         'flightNumber': '7645',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'tags': ['second_shortest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.999},
#    {'id': '13870-2410252300--32222-0-13577-2410252325|13577-2410281230--32222-0-13870-2410281455',
#     'price': {'raw': 160.41,
#      'formatted': '161 €',
#      'pricingOptionId': 'copeTGAzVxGb'},
#     'legs': [{'id': '13870-2410252300--32222-0-13577-2410252325',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T23:00:00',
#       'arrival': '2024-10-25T23:25:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252300-2410252325--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T23:00:00',
#         'arrival': '2024-10-25T23:25:00',
#         'durationInMinutes': 85,
#         'flightNumber': '3118',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410281230--32222-0-13870-2410281455',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T12:30:00',
#       'arrival': '2024-10-28T14:55:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410281230-2410281455--32222',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T12:30:00',
#         'arrival': '2024-10-28T14:55:00',
#         'durationInMinutes': 85,
#         'flightNumber': '532',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.940825},
#    {'id': '13870-2410252135--31915-0-13577-2410252200|13577-2410282200--31915-0-13870-2410290020',
#     'price': {'raw': 130.8,
#      'formatted': '131 €',
#      'pricingOptionId': 'S8khI8JrLeL3'},
#     'legs': [{'id': '13870-2410252135--31915-0-13577-2410252200',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T21:35:00',
#       'arrival': '2024-10-25T22:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252135-2410252200--31915',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T21:35:00',
#         'arrival': '2024-10-25T22:00:00',
#         'durationInMinutes': 85,
#         'flightNumber': '9744',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410282200--31915-0-13870-2410290020',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T22:00:00',
#       'arrival': '2024-10-29T00:20:00',
#       'timeDeltaInDays': 1,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410282200-2410290020--31915',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T22:00:00',
#         'arrival': '2024-10-29T00:20:00',
#         'durationInMinutes': 80,
#         'flightNumber': '9743',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 7.5758276},
#     'fareAttributes': {},
#     'tags': ['second_cheapest', 'third_shortest'],
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.902771},
#    {'id': '13870-2410252235--32356-0-13577-2410252255|13577-2410282000--32356-0-13870-2410282225',
#     'price': {'raw': 146.36,
#      'formatted': '147 €',
#      'pricingOptionId': 'BnJiSFBANDom'},
#     'legs': [{'id': '13870-2410252235--32356-0-13577-2410252255',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T22:35:00',
#       'arrival': '2024-10-25T22:55:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252235-2410252255--32356',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T22:35:00',
#         'arrival': '2024-10-25T22:55:00',
#         'durationInMinutes': 80,
#         'flightNumber': '6724',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410282000--32356-0-13870-2410282225',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T20:00:00',
#       'arrival': '2024-10-28T22:25:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410282000-2410282225--32356',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T20:00:00',
#         'arrival': '2024-10-28T22:25:00',
#         'durationInMinutes': 85,
#         'flightNumber': '7651',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.82007},
#    {'id': '13870-2410252235--32356-0-13577-2410252255|13577-2410280715--32356-0-13870-2410280940',
#     'price': {'raw': 146.36,
#      'formatted': '147 €',
#      'pricingOptionId': 'N6NSsGkdoAGS'},
#     'legs': [{'id': '13870-2410252235--32356-0-13577-2410252255',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T22:35:00',
#       'arrival': '2024-10-25T22:55:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252235-2410252255--32356',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T22:35:00',
#         'arrival': '2024-10-25T22:55:00',
#         'durationInMinutes': 80,
#         'flightNumber': '6724',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410280715--32356-0-13870-2410280940',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T07:15:00',
#       'arrival': '2024-10-28T09:40:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410280715-2410280940--32356',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T07:15:00',
#         'arrival': '2024-10-28T09:40:00',
#         'durationInMinutes': 85,
#         'flightNumber': '7639',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.810149},
#    {'id': '13870-2410250955--32356-0-13577-2410251020|13577-2410282200--31915-0-13870-2410290020',
#     'price': {'raw': 187.3,
#      'formatted': '188 €',
#      'pricingOptionId': '6o4vem97Xx2E'},
#     'legs': [{'id': '13870-2410250955--32356-0-13577-2410251020',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T09:55:00',
#       'arrival': '2024-10-25T10:20:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410250955-2410251020--32356',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T09:55:00',
#         'arrival': '2024-10-25T10:20:00',
#         'durationInMinutes': 85,
#         'flightNumber': '7652',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410282200--31915-0-13870-2410290020',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T22:00:00',
#       'arrival': '2024-10-29T00:20:00',
#       'timeDeltaInDays': 1,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410282200-2410290020--31915',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T22:00:00',
#         'arrival': '2024-10-29T00:20:00',
#         'durationInMinutes': 80,
#         'flightNumber': '9743',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 8.4570465},
#     'fareAttributes': {},
#     'isMashUp': True,
#     'hasFlexibleOptions': False,
#     'score': 0.803563},
#    {'id': '13870-2410252300--32222-0-13577-2410252325|13577-2410281845--32222-0-13870-2410282110',
#     'price': {'raw': 173.41,
#      'formatted': '174 €',
#      'pricingOptionId': 'P3IT1pm1M14R'},
#     'legs': [{'id': '13870-2410252300--32222-0-13577-2410252325',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T23:00:00',
#       'arrival': '2024-10-25T23:25:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252300-2410252325--32222',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T23:00:00',
#         'arrival': '2024-10-25T23:25:00',
#         'durationInMinutes': 85,
#         'flightNumber': '3118',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410281845--32222-0-13870-2410282110',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T18:45:00',
#       'arrival': '2024-10-28T21:10:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32222,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#          'name': 'Iberia'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410281845-2410282110--32222',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T18:45:00',
#         'arrival': '2024-10-28T21:10:00',
#         'durationInMinutes': 85,
#         'flightNumber': '536',
#         'marketingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32222,
#          'name': 'Iberia',
#          'alternateId': 'IB',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': False,
#     'hasFlexibleOptions': False,
#     'score': 0.783298},
#    {'id': '13870-2410252135--31915-0-13577-2410252200|13577-2410281505--32356-0-13870-2410281725',
#     'price': {'raw': 151.98,
#      'formatted': '152 €',
#      'pricingOptionId': 'ezVIF5XwiCHJ'},
#     'legs': [{'id': '13870-2410252135--31915-0-13577-2410252200',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T21:35:00',
#       'arrival': '2024-10-25T22:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252135-2410252200--31915',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T21:35:00',
#         'arrival': '2024-10-25T22:00:00',
#         'durationInMinutes': 85,
#         'flightNumber': '9744',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410281505--32356-0-13870-2410281725',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T15:05:00',
#       'arrival': '2024-10-28T17:25:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410281505-2410281725--32356',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T15:05:00',
#         'arrival': '2024-10-28T17:25:00',
#         'durationInMinutes': 80,
#         'flightNumber': '7645',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'isMashUp': True,
#     'hasFlexibleOptions': False,
#     'score': 0.755576},
#    {'id': '13870-2410252135--31915-0-13577-2410252200|13577-2410282000--32356-0-13870-2410282225',
#     'price': {'raw': 143.98,
#      'formatted': '144 €',
#      'pricingOptionId': 'TyZgmfJA6mxp'},
#     'legs': [{'id': '13870-2410252135--31915-0-13577-2410252200',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T21:35:00',
#       'arrival': '2024-10-25T22:00:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252135-2410252200--31915',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T21:35:00',
#         'arrival': '2024-10-25T22:00:00',
#         'durationInMinutes': 85,
#         'flightNumber': '9744',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410282000--32356-0-13870-2410282225',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 85,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T20:00:00',
#       'arrival': '2024-10-28T22:25:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410282000-2410282225--32356',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T20:00:00',
#         'arrival': '2024-10-28T22:25:00',
#         'durationInMinutes': 85,
#         'flightNumber': '7651',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'fareAttributes': {},
#     'tags': ['third_cheapest'],
#     'isMashUp': True,
#     'hasFlexibleOptions': False,
#     'score': 0.750735},
#    {'id': '13870-2410252235--32356-0-13577-2410252255|13577-2410282200--31915-0-13870-2410290020',
#     'price': {'raw': 129.3,
#      'formatted': '130 €',
#      'pricingOptionId': 'VJSuyY8ZZnlk'},
#     'legs': [{'id': '13870-2410252235--32356-0-13577-2410252255',
#       'origin': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'destination': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-25T22:35:00',
#       'arrival': '2024-10-25T22:55:00',
#       'timeDeltaInDays': 0,
#       'carriers': {'marketing': [{'id': -32356,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#          'name': 'easyJet'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13870-13577-2410252235-2410252255--32356',
#         'origin': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'destination': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'departure': '2024-10-25T22:35:00',
#         'arrival': '2024-10-25T22:55:00',
#         'durationInMinutes': 80,
#         'flightNumber': '6724',
#         'marketingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -32356,
#          'name': 'easyJet',
#          'alternateId': 'EZ',
#          'allianceId': 0,
#          'displayCode': ''}}]},
#      {'id': '13577-2410282200--31915-0-13870-2410290020',
#       'origin': {'id': 'LIS',
#        'entityId': '95565055',
#        'name': 'Lisbon',
#        'displayCode': 'LIS',
#        'city': 'Lisbon',
#        'country': 'Portugal',
#        'isHighlighted': False},
#       'destination': {'id': 'MAD',
#        'entityId': '95565077',
#        'name': 'Madrid',
#        'displayCode': 'MAD',
#        'city': 'Madrid',
#        'country': 'Spain',
#        'isHighlighted': False},
#       'durationInMinutes': 80,
#       'stopCount': 0,
#       'isSmallestStops': False,
#       'departure': '2024-10-28T22:00:00',
#       'arrival': '2024-10-29T00:20:00',
#       'timeDeltaInDays': 1,
#       'carriers': {'marketing': [{'id': -31915,
#          'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#          'name': 'Ryanair'}],
#        'operationType': 'fully_operated'},
#       'segments': [{'id': '13577-13870-2410282200-2410290020--31915',
#         'origin': {'flightPlaceId': 'LIS',
#          'displayCode': 'LIS',
#          'parent': {'flightPlaceId': 'LISB',
#           'displayCode': 'LIS',
#           'name': 'Lisbon',
#           'type': 'City'},
#          'name': 'Lisbon',
#          'type': 'Airport',
#          'country': 'Portugal'},
#         'destination': {'flightPlaceId': 'MAD',
#          'displayCode': 'MAD',
#          'parent': {'flightPlaceId': 'MADR',
#           'displayCode': 'MAD',
#           'name': 'Madrid',
#           'type': 'City'},
#          'name': 'Madrid',
#          'type': 'Airport',
#          'country': 'Spain'},
#         'departure': '2024-10-28T22:00:00',
#         'arrival': '2024-10-29T00:20:00',
#         'durationInMinutes': 80,
#         'flightNumber': '9743',
#         'marketingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''},
#         'operatingCarrier': {'id': -31915,
#          'name': 'Ryanair',
#          'alternateId': 'FR',
#          'allianceId': 0,
#          'displayCode': ''}}]}],
#     'isSelfTransfer': False,
#     'isProtectedSelfTransfer': False,
#     'farePolicy': {'isChangeAllowed': False,
#      'isPartiallyChangeable': False,
#      'isCancellationAllowed': False,
#      'isPartiallyRefundable': False},
#     'eco': {'ecoContenderDelta': 6.803882},
#     'fareAttributes': {},
#     'tags': ['cheapest', 'shortest'],
#     'isMashUp': True,
#     'hasFlexibleOptions': False,
#     'score': 0.732008}],
#   'messages': [],
#   'filterStats': {'duration': {'min': 80,
#     'max': 85,
#     'multiCityMin': 160,
#     'multiCityMax': 170},
#    'airports': [{'city': 'Lisbon',
#      'airports': [{'id': 'LIS', 'entityId': '95565055', 'name': 'Lisbon'}]},
#     {'city': 'Madrid',
#      'airports': [{'id': 'MAD', 'entityId': '95565077', 'name': 'Madrid'}]}],
#    'carriers': [{'id': -32356,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/EZ.png',
#      'name': 'easyJet'},
#     {'id': -32222,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/IB.png',
#      'name': 'Iberia'},
#     {'id': -31915,
#      'logoUrl': 'https://logos.skyscnr.com/images/airlines/favicon/FR.png',
#      'name': 'Ryanair'}],
#    'stopPrices': {'direct': {'isPresent': True, 'formattedPrice': '130 €'},
#     'one': {'isPresent': False},
#     'twoOrMore': {'isPresent': False}}},
#   'flightsSessionId': '8861858c-a929-47b3-8059-7946da419997',
#   'destinationImageUrl': 'https://content.skyscnr.com/m/3719e8f4a5daf43d/original/Flights-Placeholder.jpg'}}

# %%
lista_de_diccionarios = []
# creo mi lista de diccionarios
for i in range(0,info_vuelo):
    #aquí itero sobre la cantidad de vuelos, 20 en total pero en pares de solo 10
    precios = viajes['data']['itineraries'][i]['price']['raw']
    for j in range(0,2):
        #itero sobre los elementos de ida y vuelta
        id_inicio = viajes['data']['itineraries'][i]['legs'][j]['origin']['id']
        inicio_ciudad = viajes['data']['itineraries'][i]['legs'][j]['origin']['name']
        id_regreso = viajes['data']['itineraries'][i]['legs'][j]['destination']['id']
        regreso_ciudad = viajes['data']['itineraries'][i]['legs'][j]['destination']['name']
        tiempo = viajes['data']['itineraries'][i]['legs'][j]['durationInMinutes']
        paradas = viajes['data']['itineraries'][i]['legs'][j]['stopCount']
        linea_aerea = viajes['data']['itineraries'][i]['legs'][j]['carriers']['marketing'][0]['name']
        hora_salida = viajes['data']['itineraries'][i]['legs'][j]['departure']
        hora_llegada = viajes['data']['itineraries'][i]['legs'][j]['arrival']
        diccionario = {'Costo': precios,
                'ID Salida': id_inicio,
                'Salida': inicio_ciudad,
                'ID Llegada': id_regreso,
                'Llegada': regreso_ciudad,
                'Tiempo': tiempo,
                'Paradas': paradas,
                'Aerolínea': linea_aerea,
                'Hora de Salida': hora_salida,
                'Hora de Llegada': hora_llegada}
        lista_de_diccionarios.append(diccionario)

#creo mi diccionario y le apendeo las listas cada vez que itero

# %%
df = pd.DataFrame(lista_de_diccionarios)

# %%
df
# Out:
#      Costo ID Salida  Salida ID Llegada Llegada  Tiempo  Paradas Aerolínea  \
# 0   154.36       MAD  Madrid        LIS  Lisbon      80        0   easyJet
# 1   154.36       LIS  Lisbon        MAD  Madrid      80        0   easyJet
# 2   160.41       MAD  Madrid        LIS  Lisbon      85        0    Iberia
# 3   160.41       LIS  Lisbon        MAD  Madrid      85        0    Iberia
# 4   130.80       MAD  Madrid        LIS  Lisbon      85        0   Ryanair
p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

viaje_florencia = response.json()

# %%
viaje_florencia.keys()
# Out:
# dict_keys(['status', 'timestamp', 'sessionId', 'data'])

# %%
info_cantidad = len(viaje_florencia['data']['itineraries'])

# %%
precio_fl = viaje_florencia['data']['itineraries'][0]['price']['raw']

# %%
id_fl = viaje_florencia['data']['itineraries'][0]['legs'][0]['origin']['id']

# %%
salida_fl = viaje_florencia['data']['itineraries'][0]['legs'][0]['origin']['name']
# Out:
# 'Florence'

# %%
id_vuelta = viaje_florencia['data']['itineraries'][0]['legs'][0]['destination']['id']

# %%
regreso_fl = viaje_florencia['data']['itineraries'][0]['legs'][0]['destination']['name']

# %%
tiempo_fl = viaje_florencia['data']['itineraries'][0]['legs'][0]['durationInMinutes']
tiempo_fl
# Out:
# 140

# %%
stops = viaje_florencia['data']['itineraries'][0]['legs'][0]['stopCount']
# Out:
# 0

# %%
linea_devuelo = viaje_florencia['data']['itineraries'][0]['legs'][0]['carriers']['marketing'][0]['name']
linea_devuelo
# Out:
# 'Vueling Airlines'

# %%
salida = viaje_florencia['data']['itineraries'][0]['legs'][0]['departure']
salida
# Out:
# '2024-10-25T09:55:00'

# %%
llegada = viaje_florencia['data']['itineraries'][0]['legs'][0]['arrival']
llegada
# Out:
# '2024-10-25T12:15:00'

# %%
list_dict = []
for i in range(0,info_cantidad):
    precio_fl = viaje_florencia['data']['itineraries'][i]['price']['raw']    
    for j in range(0,2):
        id_fl = viaje_florencia['data']['itineraries'][i]['legs'][j]['origin']['id']
        salida_fl = viaje_florencia['data']['itineraries'][i]['legs'][j]['origin']['name']
        id_vuelta = viaje_florencia['data']['itineraries'][i]['legs'][j]['destination']['id']
        regreso_fl = viaje_florencia['data']['itineraries'][i]['legs'][j]['destination']['name']
        tiempo_fl = viaje_florencia['data']['itineraries'][i]['legs'][j]['durationInMinutes']
        stops = viaje_florencia['data']['itineraries'][i]['legs'][j]['stopCount']
        linea_devuelo = viaje_florencia['data']['itineraries'][i]['legs'][j]['carriers']['marketing'][0]['name']
        salida = viaje_florencia['data']['itineraries'][i]['legs'][j]['departure']
        llegada = viaje_florencia['data']['itineraries'][i]['legs'][j]['arrival']
        dicty = {'Costo': precio_fl,
                'ID Salida': id_fl,
                'Salida': salida_fl,
                'ID Llegada': id_vuelta,
                'Llegada': regreso_fl,
                'Tiempo': tiempo_fl,
                'Paradas': stops,
                'Aerolínea': linea_devuelo,
                'Hora de Salida': salida,
                'Hora de Llegada': llegada}
        list_dict.append(dicty)

# %%
df_florence = pd.DataFrame(list_dict)

# %%
df_florence.head()
# Out:
#    Costo ID Salida    Salida ID Llegada   Llegada  Tiempo  Paradas  \
# 0  428.0       MAD    Madrid        FLR  Florence     140        0
# 1  428.0       FLR  Florence        MAD    Madrid     150        0
# 2  429.0       MAD    Madrid        FLR  Florence     140        0
# 3  429.0       FLR  Florence        MAD    Madrid     150        0
# 4  290.0       MAD    Madrid        FLR  Florence     250        1
#
#           Aerolínea       Hora de Salida      Hora de Llegada
# 0  Vueling Airlines  2024-10-25T09:55:00  2024-10-25T12:15:00
# 1  Vueling Airlines  2024-10-28T12:35:00  2024-10-28T15:05:00
# 2  Vueling Airlines  2024-10-25T15:35:00  2024-10-25T17:55:00
